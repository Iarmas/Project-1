# %%
import csv
import pandas as pd

RSocial="RSocial_AGEB 2010.csv"
RSocial_df = pd.read_csv(RSocial, encoding="ISO-8859-1")
RSocial_df
# Out:
#       Grado de Rezago Social por AGEB urbana, nacional 2010  \
# 0                                                    NaN
# 1                                    Clave de la entidad
# 2                                                    NaN
# 3                                                    NaN
# 4                                                     01
# 5                                                     01
# 6                                                     01
# 7                                                     01
# 8                                                     01
# 9                                                     01
# 10                                                    01
# 11                                                    01
# 12                                                    01
# 13                                                    01
# 14                                                    01
# ...

# %%
import pandas as pd

# %%
file = "../GranTablaCDMX&Metro.csv"

readF = pd.read_csv(file)
readF.head()
# Out:
#    Unnamed: 0  ENTIDAD           NOM_ENT  MUN       NOM_MUN  LOC  \
# 0           0        9  Distrito Federal    2  Azcapotzalco    1
# 1           1        9  Distrito Federal    2  Azcapotzalco    1
# 2           2        9  Distrito Federal    2  Azcapotzalco    1
# 3           3        9  Distrito Federal    2  Azcapotzalco    1
# 4           4        9  Distrito Federal    2  Azcapotzalco    1
#
#              NOM_LOC  AGEB  MZA  POBTOT  ...  \
# 0  Total AGEB urbana  0010    0    3424  ...
# 1  Total AGEB urbana  0025    0    5912  ...
# 2  Total AGEB urbana  003A    0    4638  ...
# 3  Total AGEB urbana  0044    0    5007  ...
# 4  Total AGEB urbana  0097    0    2260  ...
#
#   Viviendas que no disponen de lavadora  \
# 0                                   6.5
# 1                                  14.4
# 2                                  11.4
# 3                                  11.4
# 4                                   8.1
#
#   Viviendas que no disponen de refrigerador  \
# ...

# %%
readF
# Out:
#       Unnamed: 0  ENTIDAD           NOM_ENT  MUN                      NOM_MUN  \
# 0              0        9  Distrito Federal    2                 Azcapotzalco
# 1              1        9  Distrito Federal    2                 Azcapotzalco
# 2              2       15            México   30                   Chiconcuac
# 3              3       15            México   30                   Chiconcuac
# 4              4        9  Distrito Federal    2                 Azcapotzalco
# 5              5        9  Distrito Federal    2                 Azcapotzalco
# 6              6        9  Distrito Federal    2                 Azcapotzalco
# 7              7        9  Distrito Federal    2                 Azcapotzalco
# 8              8       15            México   30                   Chiconcuac
# 9              9       15            México   30                   Chiconcuac
# 10            10       15            México   30                   Chiconcuac
# ...

# %%
# %matplotlib notebook

import csv
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

GT = 'GranTablaCDMX&Metro.csv'
GT_df = pd.read_csv(GT,encoding="utf-8")
GT_df
# Out:
#       Unnamed: 0  ENTIDAD           NOM_ENT  MUN                      NOM_MUN  \
# 0              0        9  Distrito Federal    2                 Azcapotzalco
# 1              1        9  Distrito Federal    2                 Azcapotzalco
# 2              2        9  Distrito Federal    2                 Azcapotzalco
# 3              3        9  Distrito Federal    2                 Azcapotzalco
# 4              4        9  Distrito Federal    2                 Azcapotzalco
# 5              5        9  Distrito Federal    2                 Azcapotzalco
# 6              6        9  Distrito Federal    2                 Azcapotzalco
# 7              7        9  Distrito Federal    2                 Azcapotzalco
# 8              8        9  Distrito Federal    2                 Azcapotzalco
# 9              9        9  Distrito Federal    2                 Azcapotzalco
# 10            10        9  Distrito Federal    2                 Azcapotzalco
# ...

# %%
GT_df.columns
# Out:
# Index(['Unnamed: 0', 'ENTIDAD', 'NOM_ENT', 'MUN', 'NOM_MUN', 'LOC', 'NOM_LOC',
#        'AGEB', 'MZA', 'POBTOT', 'POBMAS', 'POBFEM', 'REL_H_M', 'P_18YMAS',
#        'P_60YMAS', 'P_0A2', 'P_3A5', 'P_6A11', 'P_12A14', 'P_15A17', 'P_18A24',
#        'PEA', 'PE_INAC', 'POCUPADA', 'PDESOCUP', 'PSINDER', 'PDER_SS',
#        'TVIVHAB', 'VIVPAR_HAB', 'PROM_OCUP', 'GRAPROES', 'Entidad federativa',
#        'Nombre del municipio', 'Nombre de la localidad', 'Folio de la AGEB',
#        'Población total ', 'Viviendas particulares habitadas',
#        'Población de 15 años y más con educación básica incompleta',
#        'Población de 15 a 24 años que no asiste a la escuela',
#        'Población sin derechohabiencia a servicios de salud',
#        'Personas que viven en hacinamiento',
#        'Viviendas que no disponen de excusado o sanitario',
#        'Viviendas que no disponen de lavadora',
#        'Viviendas que no disponen de refrigerador',
# ...

# %%
GT_df.reset_index()

GT_df['P_0A2'] = GT_df['P_0A2'].str.replace('*', '0')

edad_0a2_MUN = GT_df.loc[:,['NOM_ENT','NOM_MUN','AGEB','P_0A2','POBTOT']]
edad_0a2_MUN

edad_0a2_MUN['Porcentaje Pob. 0 a 2 años'] = edad_0a2_MUN['P_0A2'].astype(float)/edad_0a2_MUN['POBTOT'].astype(float)*100
edad_0a2_df = edad_0a2_MUN
edad_0a2_df
# Out:
#                NOM_ENT                      NOM_MUN  AGEB P_0A2  POBTOT  \
# 0     Distrito Federal                 Azcapotzalco  0010    71    3424
# 1     Distrito Federal                 Azcapotzalco  0025   206    5912
# 2     Distrito Federal                 Azcapotzalco  003A   157    4638
# 3     Distrito Federal                 Azcapotzalco  0044   148    5007
# 4     Distrito Federal                 Azcapotzalco  0097    56    2260
# 5     Distrito Federal                 Azcapotzalco  010A    79    3385
# 6     Distrito Federal                 Azcapotzalco  0114   450   10265
# 7     Distrito Federal                 Azcapotzalco  0129   248    5005
# 8     Distrito Federal                 Azcapotzalco  0133   255    7028
# 9     Distrito Federal                 Azcapotzalco  0148    73    2645
# 10    Distrito Federal                 Azcapotzalco  0167   114    3169
# 11    Distrito Federal                 Azcapotzalco  0171    72    2466
# ...

# %%
GT_df.reset_index()

GT_df['P_3A5'] = GT_df['P_3A5'].str.replace('*', '0')

edad_3a5_MUN = GT_df.loc[:,['NOM_ENT','NOM_MUN','AGEB','P_3A5','POBTOT']]
edad_3a5_MUN

edad_3a5_MUN['Porcentaje Pob. 3 a 5 años'] = edad_3a5_MUN['P_3A5'].astype(float)/edad_3a5_MUN['POBTOT'].astype(float)*100
edad_3a5_df = edad_3a5_MUN
edad_3a5_df
# Out:
#                NOM_ENT                      NOM_MUN  AGEB P_3A5  POBTOT  \
# 0     Distrito Federal                 Azcapotzalco  0010    77    3424
# 1     Distrito Federal                 Azcapotzalco  0025   241    5912
# 2     Distrito Federal                 Azcapotzalco  003A   137    4638
# 3     Distrito Federal                 Azcapotzalco  0044   162    5007
# 4     Distrito Federal                 Azcapotzalco  0097    82    2260
# 5     Distrito Federal                 Azcapotzalco  010A   106    3385
# 6     Distrito Federal                 Azcapotzalco  0114   483   10265
# 7     Distrito Federal                 Azcapotzalco  0129   221    5005
# 8     Distrito Federal                 Azcapotzalco  0133   267    7028
# 9     Distrito Federal                 Azcapotzalco  0148    96    2645
# 10    Distrito Federal                 Azcapotzalco  0167   143    3169
# 11    Distrito Federal                 Azcapotzalco  0171    83    2466
# ...

# %%
GT_df.reset_index()

GT_df['P_6A11'] = GT_df['P_6A11'].str.replace('*', '0')

edad_6a11_MUN = GT_df.loc[:,['NOM_ENT','NOM_MUN','AGEB','P_6A11','POBTOT']]
edad_6a11_MUN

edad_6a11_MUN['Porcentaje Pob. 6 a 11 años'] = edad_6a11_MUN['P_6A11'].astype(float)/edad_6a11_MUN['POBTOT'].astype(float)*100
edad_6a11_df = edad_6a11_MUN
edad_6a11_df
# Out:
#                NOM_ENT                      NOM_MUN  AGEB P_6A11  POBTOT  \
# 0     Distrito Federal                 Azcapotzalco  0010    235    3424
# 1     Distrito Federal                 Azcapotzalco  0025    466    5912
# 2     Distrito Federal                 Azcapotzalco  003A    347    4638
# 3     Distrito Federal                 Azcapotzalco  0044    391    5007
# 4     Distrito Federal                 Azcapotzalco  0097    150    2260
# 5     Distrito Federal                 Azcapotzalco  010A    225    3385
# 6     Distrito Federal                 Azcapotzalco  0114    952   10265
# 7     Distrito Federal                 Azcapotzalco  0129    482    5005
# 8     Distrito Federal                 Azcapotzalco  0133    635    7028
# 9     Distrito Federal                 Azcapotzalco  0148    195    2645
# 10    Distrito Federal                 Azcapotzalco  0167    272    3169
# 11    Distrito Federal                 Azcapotzalco  0171    157    2466
# ...

# %%
GT_df.reset_index()

GT_df['P_12A14'] = GT_df['P_12A14'].str.replace('*', '0')

edad_12a14_MUN = GT_df.loc[:,['NOM_ENT','NOM_MUN','AGEB','P_12A14','POBTOT']]
edad_12a14_MUN

edad_12a14_MUN['Porcentaje Pob. 12 a 14 años'] = edad_12a14_MUN['P_12A14'].astype(float)/edad_12a14_MUN['POBTOT'].astype(float)*100
edad_12a14_df = edad_12a14_MUN
edad_12a14_df
# Out:
#                NOM_ENT                      NOM_MUN  AGEB P_12A14  POBTOT  \
# 0     Distrito Federal                 Azcapotzalco  0010     129    3424
# 1     Distrito Federal                 Azcapotzalco  0025     212    5912
# 2     Distrito Federal                 Azcapotzalco  003A     202    4638
# 3     Distrito Federal                 Azcapotzalco  0044     178    5007
# 4     Distrito Federal                 Azcapotzalco  0097      80    2260
# 5     Distrito Federal                 Azcapotzalco  010A     120    3385
# 6     Distrito Federal                 Azcapotzalco  0114     491   10265
# 7     Distrito Federal                 Azcapotzalco  0129     208    5005
# 8     Distrito Federal                 Azcapotzalco  0133     329    7028
# 9     Distrito Federal                 Azcapotzalco  0148      93    2645
# 10    Distrito Federal                 Azcapotzalco  0167     138    3169
# 11    Distrito Federal                 Azcapotzalco  0171      93    2466
# ...

# %%
GT_df.reset_index()

GT_df['P_15A17'] = GT_df['P_15A17'].str.replace('*', '0')

edad_15a17_MUN = GT_df.loc[:,['NOM_ENT','NOM_MUN','AGEB','P_15A17','POBTOT']]
edad_15a17_MUN

edad_15a17_MUN['Porcentaje Pob. 15 a 17 años'] = edad_15a17_MUN['P_15A17'].astype(float)/edad_15a17_MUN['POBTOT'].astype(float)*100
edad_15a17_df = edad_15a17_MUN
edad_15a17_df
# Out:
#                NOM_ENT                      NOM_MUN  AGEB P_15A17  POBTOT  \
# 0     Distrito Federal                 Azcapotzalco  0010     137    3424
# 1     Distrito Federal                 Azcapotzalco  0025     261    5912
# 2     Distrito Federal                 Azcapotzalco  003A     197    4638
# 3     Distrito Federal                 Azcapotzalco  0044     203    5007
# 4     Distrito Federal                 Azcapotzalco  0097      88    2260
# 5     Distrito Federal                 Azcapotzalco  010A     150    3385
# 6     Distrito Federal                 Azcapotzalco  0114     554   10265
# 7     Distrito Federal                 Azcapotzalco  0129     227    5005
# 8     Distrito Federal                 Azcapotzalco  0133     418    7028
# 9     Distrito Federal                 Azcapotzalco  0148      88    2645
# 10    Distrito Federal                 Azcapotzalco  0167     145    3169
# 11    Distrito Federal                 Azcapotzalco  0171     113    2466
# ...

# %%
GT_df.reset_index()

GT_df['P_18A24'] = GT_df['P_18A24'].str.replace('*', '0')

edad_18a24_MUN = GT_df.loc[:,['NOM_ENT','NOM_MUN','AGEB','P_18A24','POBTOT']]
edad_18a24_MUN

edad_18a24_MUN['Porcentaje Pob. 18 a 24 años'] = edad_18a24_MUN['P_18A24'].astype(float)/edad_18a24_MUN['POBTOT'].astype(float)*100
edad_18a24_MUN.head()
edad_18a24_df = edad_18a24_MUN
edad_18a24_df
# Out:
#                NOM_ENT                      NOM_MUN  AGEB P_18A24  POBTOT  \
# 0     Distrito Federal                 Azcapotzalco  0010     298    3424
# 1     Distrito Federal                 Azcapotzalco  0025     622    5912
# 2     Distrito Federal                 Azcapotzalco  003A     478    4638
# 3     Distrito Federal                 Azcapotzalco  0044     459    5007
# 4     Distrito Federal                 Azcapotzalco  0097     202    2260
# 5     Distrito Federal                 Azcapotzalco  010A     289    3385
# 6     Distrito Federal                 Azcapotzalco  0114    1400   10265
# 7     Distrito Federal                 Azcapotzalco  0129     605    5005
# 8     Distrito Federal                 Azcapotzalco  0133     867    7028
# 9     Distrito Federal                 Azcapotzalco  0148     218    2645
# 10    Distrito Federal                 Azcapotzalco  0167     368    3169
# 11    Distrito Federal                 Azcapotzalco  0171     264    2466
# ...

# %%
GT_df.reset_index()

GT_df['P_18YMAS'] = GT_df['P_18YMAS'].str.replace('*', '0')

edad_18ms_MUN = GT_df.loc[:,['NOM_ENT','NOM_MUN','AGEB','P_18YMAS','POBTOT']]
edad_18ms_MUN

edad_18ms_MUN['Porcentaje Pob. con 18 o más años'] = edad_18ms_MUN['P_18YMAS'].astype(float)/edad_18ms_MUN['POBTOT'].astype(float)*100
edad_18ms_df = edad_18ms_MUN
edad_18ms_df
# Out:
#                NOM_ENT                      NOM_MUN  AGEB P_18YMAS  POBTOT  \
# 0     Distrito Federal                 Azcapotzalco  0010     2650    3424
# 1     Distrito Federal                 Azcapotzalco  0025     4426    5912
# 2     Distrito Federal                 Azcapotzalco  003A     3418    4638
# 3     Distrito Federal                 Azcapotzalco  0044     3708    5007
# 4     Distrito Federal                 Azcapotzalco  0097     1756    2260
# 5     Distrito Federal                 Azcapotzalco  010A     2499    3385
# 6     Distrito Federal                 Azcapotzalco  0114     7158   10265
# 7     Distrito Federal                 Azcapotzalco  0129     3442    5005
# 8     Distrito Federal                 Azcapotzalco  0133     5021    7028
# 9     Distrito Federal                 Azcapotzalco  0148     1901    2645
# 10    Distrito Federal                 Azcapotzalco  0167     2322    3169
# ...

# %%
#GT_df.reset_index()

GT_df['P_60YMAS'] = GT_df['P_60YMAS'].str.replace('*', '0')

edad_60ms_MUN = GT_df.loc[:,['NOM_ENT','NOM_MUN','AGEB','P_60YMAS','POBTOT']]
edad_60ms_MUN

edad_60ms_MUN['Porcentaje Pob. con 60 o más años'] = edad_60ms_MUN['P_60YMAS'].astype(float)/edad_60ms_MUN['POBTOT'].astype(float)*100
edad_60ms_df = edad_60ms_MUN
edad_60ms_df
# Out:
#                NOM_ENT                      NOM_MUN  AGEB P_60YMAS  POBTOT  \
# 0     Distrito Federal                 Azcapotzalco  0010      822    3424
# 1     Distrito Federal                 Azcapotzalco  0025      974    5912
# 2     Distrito Federal                 Azcapotzalco  003A      902    4638
# 3     Distrito Federal                 Azcapotzalco  0044      993    5007
# 4     Distrito Federal                 Azcapotzalco  0097      523    2260
# 5     Distrito Federal                 Azcapotzalco  010A      735    3385
# 6     Distrito Federal                 Azcapotzalco  0114      905   10265
# 7     Distrito Federal                 Azcapotzalco  0129      384    5005
# 8     Distrito Federal                 Azcapotzalco  0133      709    7028
# 9     Distrito Federal                 Azcapotzalco  0148      464    2645
# 10    Distrito Federal                 Azcapotzalco  0167      357    3169
# ...

# %%
import pandas as pd
from functools import reduce

dfs = [edad_0a2_df, edad_3a5_df,edad_6a11_df, edad_12a14_df, edad_15a17_df, edad_18a24_df,edad_18ms_df, edad_60ms_df] 

edades_final = reduce(lambda left,right:pd.merge(left,right,on=['NOM_ENT','NOM_MUN','AGEB','POBTOT']),dfs)
edades_final
# Out:
#                NOM_ENT                      NOM_MUN  AGEB P_0A2  POBTOT  \
# 0     Distrito Federal                 Azcapotzalco  0010    71    3424
# 1     Distrito Federal                 Azcapotzalco  0025   206    5912
# 2     Distrito Federal                 Azcapotzalco  003A   157    4638
# 3     Distrito Federal                 Azcapotzalco  0044   148    5007
# 4     Distrito Federal                 Azcapotzalco  0097    56    2260
# 5     Distrito Federal                 Azcapotzalco  010A    79    3385
# 6     Distrito Federal                 Azcapotzalco  0114   450   10265
# 7     Distrito Federal                 Azcapotzalco  0129   248    5005
# 8     Distrito Federal                 Azcapotzalco  0133   255    7028
# 9     Distrito Federal                 Azcapotzalco  0148    73    2645
# 10    Distrito Federal                 Azcapotzalco  0167   114    3169
# 11    Distrito Federal                 Azcapotzalco  0171    72    2466
# ...

# %%
edades_final.to_csv('Edades.csv',index = False)

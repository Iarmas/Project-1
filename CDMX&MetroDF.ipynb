# %%
import csv
import pandas as pd

cdmx=pd.read_csv("Estados/Total_CDMX.csv")
cdmx2=pd.read_csv("Estados/Total_CDMX2.csv")
edm=pd.read_csv("Estados/Total_EdoMex.csv")
edm2=pd.read_csv("Estados/Total_EdoMex2.csv")
edm3=pd.read_csv("Estados/Total_EdoMex3.csv")

dfs = [cdmx,cdmx2,edm,edm2,edm3]

df_final = pd.concat(dfs)
df_final
# Out:
#       ENTIDAD           NOM_ENT  MUN           NOM_MUN  LOC  \
# 0           9  Distrito Federal    0  Distrito Federal    0
# 1           9  Distrito Federal    2      Azcapotzalco    0
# 2           9  Distrito Federal    2      Azcapotzalco    1
# 3           9  Distrito Federal    2      Azcapotzalco    1
# 4           9  Distrito Federal    2      Azcapotzalco    1
# 5           9  Distrito Federal    2      Azcapotzalco    1
# 6           9  Distrito Federal    2      Azcapotzalco    1
# 7           9  Distrito Federal    2      Azcapotzalco    1
# 8           9  Distrito Federal    2      Azcapotzalco    1
# 9           9  Distrito Federal    2      Azcapotzalco    1
# 10          9  Distrito Federal    2      Azcapotzalco    1
# 11          9  Distrito Federal    2      Azcapotzalco    1
# 12          9  Distrito Federal    2      Azcapotzalco    1
# 13          9  Distrito Federal    2      Azcapotzalco    1
# 14          9  Distrito Federal    2      Azcapotzalco    1
# ...

# %%
df_final.columns
# Out:
# Index(['ENTIDAD', 'NOM_ENT', 'MUN', 'NOM_MUN', 'LOC', 'NOM_LOC', 'AGEB', 'MZA',
#        'POBTOT', 'POBMAS', 'POBFEM', 'REL_H_M', 'P_18YMAS', 'P_60YMAS',
#        'P_0A2', 'P_3A5', 'P_6A11', 'P_12A14', 'P_15A17', 'P_18A24', 'PEA',
#        'PE_INAC', 'POCUPADA', 'PDESOCUP', 'PSINDER', 'PDER_SS', 'TVIVHAB',
#        'VIVPAR_HAB', 'PROM_OCUP', 'GRAPROES'],
#       dtype='object')

# %%
#eco_active_mun = df_final.groupby(['NOM_MUN']).agg('count', axis='Total AGEB urbana')
#eco_active_mun

#eco_active_mun = df_final.groupby(['AGEB']).agg({'PEA':'sum','POBTOT':'sum'})
#eco_active_mun

#total_AGEB_urban = df_final.loc[df_final['NOM_MUN'] == 'Total AGEB urbana',['AGEB','PEA','POBTOT']]
#total_AGEB_urban
# Out:
# Empty DataFrame
# Columns: [AGEB, PEA, POBTOT]
# Index: []

# %%
#eco_inactive_mun = df_final.groupby(['AGEB']).agg({'PE_INAC':'value_counts','POBTOT':'sum'})
#eco_inactive_mun
